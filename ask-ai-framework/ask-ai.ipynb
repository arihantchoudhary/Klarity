# %%
import os

# %% [markdown]
# # Changed the

# %%
os.chdir('/Users/arihantchoudhary/GitHub/Klarity/uploads')
os.getcwd()
os.listdir()
# Out:
# ['Anlaysis_Essay.docx', 'Anlaysis_Essay.pdf', 'Pfizer']

# %% [markdown]
# # Importing Document Dataset

# %%
# Pfizer dataset is in uploads folder, it has a bunch of pdfs in it/

# %%
import os
import time
from tqdm import tqdm

# Define the target directory
root_dir = "/Users/arihantchoudhary/GitHub/Klarity/uploads/Pfizer"

# Count total files and folders
file_list = []
for root, dirs, files in os.walk(root_dir):
    print(root, dirs, files)
    for file in files:
        file_list.append(os.path.join(root, file))

file_list
# Out:
# /Users/arihantchoudhary/GitHub/Klarity/uploads/Pfizer ['Rel_22122021', 'Rel_01082022', 'Rel_01092022', 'Rel_13012022', 'Rel_01122021', 'Rel_30122021', 'Rel_24032022', 'Rel_02052022', 'Rel_01032022', 'court_documents', 'Rel_18012022', 'Rel_01042022', 'Rel_01112022', 'Rel_01072022', 'Rel_13122021', 'Rel_03102022', 'Rel_01062022'] []
# /Users/arihantchoudhary/GitHub/Klarity/uploads/Pfizer/Rel_22122021 [] ['Supplemental-Index-12-22-21.pdf']
# ...

# %%
# Track progress with tqdm
start_time = time.time()
for file_path in tqdm(file_list, desc="Processing files", unit="file", dynamic_ncols=True):
    time.sleep(0.1)  # Simulating a process (remove this in actual usage)
    # You can add file processing logic here, e.g., reading or analyzing the files

end_time = time.time()
print(f"\nProcessed {len(file_list)} files in {end_time - start_time:.2f} seconds.")
# Out:
# Processing files:  47%|████▋     | 198/419 [00:20<00:23,  9.46file/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 start_time = time.time()
#       3 for file_path in tqdm(file_list, desc="Processing files", unit="file", dynamic_ncols=True):
# ----> 4     time.sleep(0.1)  # Simulating a process (remove this in actual usage)
#       5     # You can add file processing logic here, e.g., reading or analyzing the files
#       7 end_time = time.time()
#
# KeyboardInterrupt:

# %% [markdown]
# # OCR

# %%
import pytesseract
from pdf2image import convert_from_path
from PIL import Image
import io

# Path to the file
file_path = "anlaysis_essay.pdf"

# Convert PDF to images
try:
    images = convert_from_path(file_path)
    
    # Extract text from all pages
    text = ""
    for i, image in enumerate(images):
        text += pytesseract.image_to_string(image)
    
    document = text
    print(f"Processed {len(images)} pages from {file_path}")
except Exception as e:
    print(f"Error processing PDF: {str(e)}")
    document = None

# %% [markdown]
# #### Single File Processing

# %%
def read_file(file_path):
    """Read a file from the given path and return its contents."""
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
        return content
    except FileNotFoundError:
        print(f"Error: File {file_path} not found.")
        return None
    except Exception as e:
        print(f"Error reading file: {str(e)}")
        return None

file_name = "Anlaysis_Essay.pdf"  # Replace with the file you want to read


file_content = read_file(file_name)
if file_content:
    print(f"Successfully read file: {file_name}")
    # Uncomment to print content (be careful with large files)
    # print(file_content)
# Out:
# Error reading file: 'utf-8' codec can't decode byte 0xd3 in position 10: invalid continuation byte

# %%
api_key = os.environ["MISTRAL_API_KEY"]
model = "mistral-large-latest"

client = Mistral(api_key=api_key)

chat_response = client.chat.complete(
    model= model,
    messages = [
        {
            "role": "user",
            "content": "What is the best French cheese?",
        },
    ]
)
print(chat_response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 api_key = os.environ["MISTRAL_API_KEY"]
#       2 model = "mistral-large-latest"
#       4 client = Mistral(api_key=api_key)
#
# File ~/miniconda3/envs/klarity/lib/python3.10/os.py:680, in _Environ.__getitem__(self, key)
#     677     value = self._data[self.encodekey(key)]
#     678 except KeyError:
#     679     # raise KeyError with the original key value
# --> 680     raise KeyError(key) from None
#     681 return self.decodevalue(value)
#
# KeyError: 'MISTRAL_API_KEY'
